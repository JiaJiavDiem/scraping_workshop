# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jun 11 18:18:44 2019

@author: chris
"""

# This file contains the script to read the URLs from the SQLite database
# Start: SQLite database
# End: URLs in database

# Step2A: Read the URLs from the SQLite database
# Step2B: Scrape the URLs and write the content to the database
# Step2C: Retrieve URLs from content, write URLs to database
# Step2D: Use URLs to scrape, retrieve contents and write to database

import pandas as pd
import sqlite3
from sqlite3 import Error
import requests
import bs4
from bs4 import BeautifulSoup
from bs4.element import Comment
from lxml.html.soupparser import fromstring
import urllib.request

# %%
def create_connection(db_file):
    try:
        conn = sqlite3.connect(db_file)
        print("conn open")
        print(sqlite3.version)
        return conn
    except Error as e:
        print(e)

    return None

# %%
def retrieve_data(sql, conn):
    df_data = pd.read_sql_query(sql, conn)
    return df_data

# %%
def scrape1(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}
    response_scrape1 = requests.get('http://' + url, headers=headers)
    return response_scrape1

# %%
def process_scrape1(resp_obj):
    soup = bs4.BeautifulSoup(resp_obj.text, 'lxml')
    text_total = soup.get_text().strip()
    return text_total

# %%
#def removeNonAscii(s): return "".join(i for i in s if ord(i)<128)

# def scrape2(url2):
#     hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}
#     url = "https://" + url2
#     html_req = urllib.request.Request(url, headers = hdr)
#     html_resp = urllib.request.urlopen(html_req)
#     html = html_resp.read()
#     return(html)
    
# def process_scrape2(scrape2_text):
#     html_text = text_from_html(scrape2_text)
#     return(html_text)
    
# def tag_visible(element):
#     if element.parent.name in ['style', 'script', 'head', 'title', 'meta', 'document]']:
#         return False
#     if isinstance(element, Comment):
#         return False
#     return True    

# def text_from_html(body):
#     soup = BeautifulSoup(body, 'lxml')
#     texts = soup.findAll(text=True)
#     visible_texts = filter(tag_visible, texts)
#     return u" ".join(t.strip() for t in visible_texts)

# %%
def process_scrape(scrape2_text):
    html_text = text_from_html(scrape2_text)
    return(html_text)

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', 'document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

# %%
def text_from_html(body):
    soup = BeautifulSoup(body, 'lxml')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)
    return u" ".join(t.strip() for t in visible_texts)

# %%
# def write_to_db(df, conn):
#     sql2 = """INSERT INTO secondScrape VALUES
#             (
#             ?,?,?,?,?
#             )"""      
#     list_values2 = [main_company, id_link, url, scrape1_response, process1_text]       
#     cur = conn.cursor()
#     cur.execute(sql2, list_values2)
#     conn.commit()

# %%
def write_to_db(df, table, conn):
    df.to_sql(table, conn, if_exists="replace")    
    
# def visible_text(element):
#     if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
#         return ''
#     result = re.sub('<!--.*-->|\r|\n', '', str(element), flags=re.DOTALL)
#     result = re.sub('\s{2,}|&nbsp;', ' ', result)
#     return result

# %%
def main():
    database = "scrape.db"
    conn = create_connection(database)
    cols = ["Company", "ID_link", "URL", "Source_code", "Text"]
    df_all = pd.DataFrame(columns = cols)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'}
    
    # Step 2C
    table = "firstScrape"
    sql = "SELECT * FROM " + table
    df_data = retrieve_data(sql, conn)
#     print(df_data.head())
    
    for index, row in df_data.iterrows():
        id_link = index
        main_company = row['Company']
        main_url_company = row['Website']
#         list_testURL = df_data.iloc[index][3]
        list_URL = row["Links_1st"]
        list_URL = list_URL[1:-1].split(",")

        for url in list_URL:
            if len(url) > 0:

                if main_url_company in url:
                    try:                        
#                         print("0")
                        print(url)
                        source_code = requests.get(url, headers=headers).text
                        print('2')
                        text = process_scrape(source_code)
#                         print("1")
                        df_all = df_all.append({"Company": main_company, "ID_link": id_link, "URL": url, "Source_code": source_code, "Text": text}, ignore_index=True)
#                         print("DONE!")
                    except:
                        print("no")
                        next
                        
                else:
                    try:
                        url_tot = 'https://' + main_url_company + url
#                         print("0")                
                        print(url_tot)
                        source_code = requests.get(url_tot, headers=headers).text
                        print('2')
                        text = process_scrape(source_code)
#                         print("1")
                        df_all = df_all.append({"Company": main_company, "ID_link": id_link, "URL": url, "Source_code": source_code, "Text": text}, ignore_index=True)
#                         print("DONE!")
                
                    except:
                        print("no")
                        next
    print(df_all)
    write_to_db(df_all, "secondScrape", conn)
    conn.close()

# %%
if __name__ == "__main__":
    main()
# Out:
# conn open
# 2.6.0
# https://www.starlingbank.com/rss.xml
# 2
# https://www.starlingbank.com/media/
# 2
# https://www.starlingbank.com/current-account/overdraft/
# 2
# https://www.starlingbank.com/online-banking/
# 2
# https://www.starlingbank.com/banking-services/
# 2
# https://www.starlingbank.com/business-account/overdraft/
# 2
# https://www.starlingbank.com/send-money-abroad/send-money-to-usa/
# 2
# https://www.starlingbank.com#
# 2
# https://www.starlingbank.com/travel/
# 2
# https://www.starlingbank.com/blog/business-talks/
# 2
# https://www.starlingbank.com/docs/Starling-Bank-16-02-article-daily-mail.pdf
# 2
# https://www.starlingbank.com/blog/turn-your-passion-into-your-profession/
# 2
# https://www.starlingbank.com/send-money-abroad/send-money-to-thailand/
# 2
# https://www.starlingbank.com/legal/privacy-notice/
# 2
# https://www.starlingbank.com/blog/women-in-finance-charter-2019-update/
# 2
# https://www.starlingbank.com/investors/
# 2
# https://www.starlingbank.com/download/
# 2
# https://www.starlingbank.com#scroll-section
# 2
# https://www.starlingbank.com/mobile-banking-security/
# 2
# https://www.starlingbank.com/send-money-abroad/send-money-to-south-africa/
# 2
# https://www.starlingbank.com/send-money-abroad/
# 2
# https://www.starlingbank.com/open-bank-account-online/
# 2
# https://www.starlingbank.com/mobile-banking-security/fraud/
# 2
# https://www.starlingbank.com/events/
# 2
# https://www.starlingbank.com/blog/ask-starling-what-we-are-building-next/
# 2
# https://www.starlingbank.com#site-header__menu-toggle
# 2
# https://www.starlingbank.com/business-account/
# 2
# https://www.starlingbank.com/loans/personal-loan/
# 2
# https://www.starlingbank.com/legal/cookie-policy/
# 2
# https://www.starlingbank.com/blog/tag/business-case/
# 2
# https://www.starlingbank.com/
# 2
# https://www.starlingbank.com/marketplace/
# 2
# https://www.starlingbank.com/security/disclosure/
# 2
# https://www.starlingbank.com/current-account/
# 2
# https://www.starlingbank.com/about/
# 2
# https://www.starlingbank.com/legal/account/fscs-protection/
# 2
# https://www.starlingbank.com/current-account/euro-bank-account/
# 2
# https://www.starlingbank.com/careers/engineering/
# 2
# https://www.starlingbank.com/careers/
# 2
# https://www.starlingbank.com/about/ethics-statement/
# 2
# https://www.starlingbank.com/features/
# 2
# https://www.starlingbank.com/reviews/
# 2
# https://www.starlingbank.com/blog/
# 2
# https://www.starlingbank.com/current-account/joint-bank-account/
# 2
# https://www.starlingbank.com/blog/john-hibbs-banking-for-all-occasions/
# 2
# https://www.starlingbank.com/send-money-abroad/send-money-to-poland/
# 2
# https://www.starlingbank.com/current-account/bank-account-for-teenagers/
# 2
# https://www.starlingbank.com/legal/
# 2
# https://www.n26.com/en-us/lovedfor
# 2
# https://www.n26.com/en-us
# 2
# https://www.n26.com/en-us/bank-account
# 2
# https://www.n26.com/en-us/legal-documents
# 2
# https://www.n26.com#main
# 2
# https://www.n26.com/en-us/blog
# 2
#           Company ID_link                                               URL  \
# 0   Starling Bank       0                                          /rss.xml
# 1   Starling Bank       0                                           /media/
# 2   Starling Bank       0                       /current-account/overdraft/
# 3   Starling Bank       0                                  /online-banking/
# 4   Starling Bank       0                                /banking-services/
# 5   Starling Bank       0                      /business-account/overdraft/
# 6   Starling Bank       0             /send-money-abroad/send-money-to-usa/
# 7   Starling Bank       0                                                 #
# 8   Starling Bank       0                                          /travel/
# 9   Starling Bank       0                             /blog/business-talks/
# 10  Starling Bank       0  /docs/Starling-Bank-16-02-article-daily-mail.pdf
# 11  Starling Bank       0     /blog/turn-your-passion-into-your-profession/
# 12  Starling Bank       0        /send-money-abroad/send-money-to-thailand/
# 13  Starling Bank       0                            /legal/privacy-notice/
# 14  Starling Bank       0       /blog/women-in-finance-charter-2019-update/
# 15  Starling Bank       0                                       /investors/
# 16  Starling Bank       0                                        /download/
# 17  Starling Bank       0                                   #scroll-section
# 18  Starling Bank       0                         /mobile-banking-security/
# 19  Starling Bank       0    /send-money-abroad/send-money-to-south-africa/
# 20  Starling Bank       0                               /send-money-abroad/
# 21  Starling Bank       0                        /open-bank-account-online/
# 22  Starling Bank       0                   /mobile-banking-security/fraud/
# 23  Starling Bank       0                                          /events/
# 24  Starling Bank       0     /blog/ask-starling-what-we-are-building-next/
# 25  Starling Bank       0                         #site-header__menu-toggle
# 26  Starling Bank       0                                /business-account/
# 27  Starling Bank       0                             /loans/personal-loan/
# 28  Starling Bank       0                             /legal/cookie-policy/
# 29  Starling Bank       0                          /blog/tag/business-case/
# 30  Starling Bank       0                                                 /
# 31  Starling Bank       0                                     /marketplace/
# 32  Starling Bank       0                             /security/disclosure/
# 33  Starling Bank       0                                 /current-account/
# 34  Starling Bank       0                                           /about/
# 35  Starling Bank       0                   /legal/account/fscs-protection/
# 36  Starling Bank       0               /current-account/euro-bank-account/
# 37  Starling Bank       0                             /careers/engineering/
# 38  Starling Bank       0                                         /careers/
# 39  Starling Bank       0                          /about/ethics-statement/
# 40  Starling Bank       0                                        /features/
# 41  Starling Bank       0                                         /reviews/
# 42  Starling Bank       0                                            /blog/
# 43  Starling Bank       0              /current-account/joint-bank-account/
# 44  Starling Bank       0       /blog/john-hibbs-banking-for-all-occasions/
# 45  Starling Bank       0          /send-money-abroad/send-money-to-poland/
# 46  Starling Bank       0      /current-account/bank-account-for-teenagers/
# 47  Starling Bank       0                                           /legal/
# 48            N26       1                                   /en-us/lovedfor
# 49            N26       1                                            /en-us
# 50            N26       1                               /en-us/bank-account
# 51            N26       1                            /en-us/legal-documents
# 52            N26       1                                             #main
# 53            N26       1                                       /en-us/blog
#
#                                           Source_code  \
# 0   <?xml version="1.0"?>\n<rss xmlns:dc="https://...
# 1   <!doctype html><html lang="en" class="SB-no-js...
# 2   <!doctype html><html lang="en" class="SB-no-js...
# 3   <!doctype html><html lang="en" class="SB-no-js...
# 4   <!doctype html><html lang="en" class="SB-no-js...
# 5   <!doctype html><html lang="en" class="SB-no-js...
# 6   <!doctype html><html lang="en" class="SB-no-js...
# 7   <!doctype html><html lang="en" class="SB-no-js...
# 8   <!doctype html><html lang="en" class="SB-no-js...
# 9   <!doctype html><html lang="en" class="SB-no-js...
# 10  %PDF-1.4\r\n%����\r\n3 0 obj\r\n<<\r\n/Lineari...
# 11  <!doctype html><html lang="en" class="SB-no-js...
# 12  <!doctype html><html lang="en" class="SB-no-js...
# 13  <!doctype html><html lang="en" class="SB-no-js...
# 14  <!doctype html><html lang="en" class="SB-no-js...
# 15  <!doctype html><html lang="en" class="SB-no-js...
# 16  <!doctype html><html lang="en" class="SB-no-js...
# 17  <!doctype html><html lang="en" class="SB-no-js...
# 18  <!doctype html><html lang="en" class="SB-no-js...
# 19  <!doctype html><html lang="en" class="SB-no-js...
# 20  <!doctype html><html lang="en" class="SB-no-js...
# 21  <!doctype html><html lang="en" class="SB-no-js...
# 22  <!doctype html><html lang="en" class="SB-no-js...
# 23  <!doctype html><html lang="en" class="SB-no-js...
# 24  <!doctype html><html lang="en" class="SB-no-js...
# 25  <!doctype html><html lang="en" class="SB-no-js...
# 26  <!doctype html><html lang="en" class="SB-no-js...
# 27  <!doctype html><html lang="en" class="SB-no-js...
# 28  <!doctype html><html lang="en" class="SB-no-js...
# 29  <!doctype html><html lang="en" class="SB-no-js...
# 30  <!doctype html><html lang="en" class="SB-no-js...
# 31  <!doctype html><html lang="en" class="SB-no-js...
# 32  <!doctype html><html lang="en" class="SB-no-js...
# 33  <!doctype html><html lang="en" class="SB-no-js...
# 34  <!doctype html><html lang="en" class="SB-no-js...
# 35  <!doctype html><html lang="en" class="SB-no-js...
# 36  <!doctype html><html lang="en" class="SB-no-js...
# 37  <!doctype html><html lang="en" class="SB-no-js...
# 38  <!doctype html><html lang="en" class="SB-no-js...
# 39  <!doctype html><html lang="en" class="SB-no-js...
# 40  <!doctype html><html lang="en" class="SB-no-js...
# 41  <!doctype html><html lang="en" class="SB-no-js...
# 42  <!doctype html><html lang="en" class="SB-no-js...
# 43  <!doctype html><html lang="en" class="SB-no-js...
# 44  <!doctype html><html lang="en" class="SB-no-js...
# 45  <!doctype html><html lang="en" class="SB-no-js...
# 46  <!doctype html><html lang="en" class="SB-no-js...
# 47  <!doctype html><html lang="en" class="SB-no-js...
# 48  \n<!doctype html>\n<html lang="en">\n  <head>\...
# 49  \n<!doctype html>\n<html lang="en">\n  <head>\...
# 50  \n<!doctype html>\n<html lang="en">\n  <head>\...
# 51  \n<!doctype html>\n<html lang="en">\n  <head>\...
# 52  \n<!doctype html>\n<html lang="en">\n  <head>\...
# 53  \n<!doctype html>\n<html lang="en">\n  <head>\...
#
#                                                  Text
# 0   xml version="1.0"?    https://www.starlingbank...
# 1   html This site uses cookies and by continuing ...
# 2   html This site uses cookies and by continuing ...
# 3   html This site uses cookies and by continuing ...
# 4   html This site uses cookies and by continuing ...
# 5   html This site uses cookies and by continuing ...
# 6   html This site uses cookies and by continuing ...
# 7   html This site uses cookies and by continuing ...
# 8   html This site uses cookies and by continuing ...
# 9   html This site uses cookies and by continuing ...
# 10  %PDF-1.4\r\n%����\r\n3 0 obj\r\n<<\r\n/Lineari...
# 11  html This site uses cookies and by continuing ...
# 12  html This site uses cookies and by continuing ...
# 13  html This site uses cookies and by continuing ...
# 14  html This site uses cookies and by continuing ...
# 15  html This site uses cookies and by continuing ...
# 16  html This site uses cookies and by continuing ...
# 17  html This site uses cookies and by continuing ...
# 18  html This site uses cookies and by continuing ...
# 19  html This site uses cookies and by continuing ...
# 20  html This site uses cookies and by continuing ...
# 21  html This site uses cookies and by continuing ...
# 22  html This site uses cookies and by continuing ...
# 23  html This site uses cookies and by continuing ...
# 24  html This site uses cookies and by continuing ...
# 25  html This site uses cookies and by continuing ...
# 26  html This site uses cookies and by continuing ...
# 27  html This site uses cookies and by continuing ...
# 28  html This site uses cookies and by continuing ...
# 29  html This site uses cookies and by continuing ...
# 30  html This site uses cookies and by continuing ...
# 31  html This site uses cookies and by continuing ...
# 32  html This site uses cookies and by continuing ...
# 33  html This site uses cookies and by continuing ...
# 34  html This site uses cookies and by continuing ...
# 35  html This site uses cookies and by continuing ...
# 36  html This site uses cookies and by continuing ...
# 37  html This site uses cookies and by continuing ...
# 38  html This site uses cookies and by continuing ...
# 39  html This site uses cookies and by continuing ...
# 40  html This site uses cookies and by continuing ...
# 41  html This site uses cookies and by continuing ...
# 42  html This site uses cookies and by continuing ...
# 43  html This site uses cookies and by continuing ...
# 44  html This site uses cookies and by continuing ...
# 45  html This site uses cookies and by continuing ...
# 46  html This site uses cookies and by continuing ...
# 47  html This site uses cookies and by continuing ...
# 48  html    Skip to main content N26 US N26 Accoun...
# 49  html    Skip to main content N26 US N26 Accoun...
# 50  html    Skip to main content N26 US N26 Accoun...
# 51  html    Skip to main content N26 US N26 Accoun...
# 52  html    Skip to main content N26 US N26 Accoun...
# 53  html    Skip to main content N26 US N26 Accoun...
